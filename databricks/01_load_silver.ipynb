# %%
# Verifica se o catálogo foi criado corretamente
spark.sql("SHOW CATALOGS").display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>catalog</th></tr></thead><tbody><tr><td>churn_lakehouse</td></tr><tr><td>dbt_tutorial_dev</td></tr><tr><td>desafio_nps_catalog</td></tr><tr><td>my_files</td></tr><tr><td>retail_q</td></tr><tr><td>samples</td></tr><tr><td>system</td></tr><tr><td>test_bruno</td></tr><tr><td>workspace</td></tr></tbody></table></div>

# %%
spark.sql("USE CATALOG churn_lakehouse")
spark.sql("USE SCHEMA silver")

print("Catalogo e schema definidos com sucesso.")
# Out:
# Catalogo e schema definidos com sucesso.
